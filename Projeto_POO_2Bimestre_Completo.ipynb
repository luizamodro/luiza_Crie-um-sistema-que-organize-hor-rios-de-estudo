# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:Luiza Curtulo Modro** oi
#
# **Turma:2bti**
#
# **Tema Escolhido:sistema que organize horários de estudo**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class HorarioEstudoluiza:
    def __init__(self, materia, dia, hora_inicio, hora_fim):
        self.materia = materia
        self.dia = dia
        self.hora_inicio = hora_inicio
        self.hora_fim = hora_fim

    def exibir_horario_luiza(self):
        print(f"Matéria: {self.materia}")
        print(f"Dia: {self.dia}")
        print(f"Horário: {self.hora_inicio} - {self.hora_fim}")
        print("-" * 30)


# Criando objetos da classe HorarioEstudo
estudo1 = HorarioEstudoluiza("Matemática", "Segunda-feira", "08:00", "10:00")
estudo2 = HorarioEstudoluiza("Física", "Terça-feira", "14:00", "16:00")

# Exibindo os horários de estudo
estudo1.exibir_horario_luiza()
estudo2.exibir_horario_luiza()
# Out:
# Matéria: Matemática
# Dia: Segunda-feira
# Horário: 08:00 - 10:00
# ------------------------------
# Matéria: Física
# Dia: Terça-feira
# Horário: 14:00 - 16:00
# ------------------------------

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class HorarioEstudoluiza:
    def __init__(self, materia, dia, hora_inicio, hora_fim):
        self.materia = materia
        self.dia = dia
        self.hora_inicio = hora_inicio
        self.hora_fim = hora_fim

    def exibir_horario_luiza(self):
        print(f"Matéria: {self.materia}")
        print(f"Dia: {self.dia}")
        print(f"Horário: {self.hora_inicio} - {self.hora_fim}")
        print("-" * 30)

    def alterar_horario_luiza(self, nova_hora_inicio, novo_hora_fim):
        self.hora_inicio = nova_hora_inicio
        self.hora_fim = novo_hora_fim
        print("Horário alterado com sucesso!")

    def adicionar_dia(self, novo_dia):
        self.dia = novo_dia
        print("Dia alterado com sucesso!")


class HorarioEstudoAvancado(HorarioEstudoluiza):
    def __init__(self, materia, dia, hora_inicio, hora_fim, local):
        super().__init__(materia, dia, hora_inicio, hora_fim)
        self.local = local

    def exibir_local(self):
        print(f"Local de estudo: {self.local}")
        print("-" * 30)


# Criando objetos da classe HorarioEstudo
estudo1 = HorarioEstudoluiza("Matemática", "Segunda-feira", "08:00", "10:00")
estudo2 = HorarioEstudoluiza("Física", "Terça-feira", "14:00", "16:00")

# Criando objetos da classe HorarioEstudoAvancado
estudo_avancado1 = HorarioEstudoAvancado("Química", "Quarta-feira", "10:00", "12:00", "Biblioteca")
estudo_avancado2 = HorarioEstudoAvancado("Biologia", "Quinta-feira", "16:00", "18:00", "Laboratório")

# Exibindo os horários de estudo
estudo1.exibir_horario_luiza()
estudo2.exibir_horario_luiza()
estudo_avancado1.exibir_horario_luiza()
estudo_avancado1.exibir_local()
estudo_avancado2.exibir_horario_luiza()
estudo_avancado2.exibir_local()

# Alterando horários e dias
estudo1.alterar_horario_luiza("09:00", "11:00")
estudo1.adicionar_dia("Sexta-feira")
estudo1.exibir_horario_luiza()
# Out:
# Matéria: Matemática
# Dia: Segunda-feira
# Horário: 08:00 - 10:00
# ------------------------------
# Matéria: Física
# Dia: Terça-feira
# Horário: 14:00 - 16:00
# ------------------------------
# Matéria: Química
# Dia: Quarta-feira
# Horário: 10:00 - 12:00
# ------------------------------
# Local de estudo: Biblioteca
# ------------------------------
# Matéria: Biologia
# Dia: Quinta-feira
# Horário: 16:00 - 18:00
# ------------------------------
# Local de estudo: Laboratório
# ------------------------------
# Horário alterado com sucesso!
# Dia alterado com sucesso!
# Matéria: Matemática
# Dia: Sexta-feira
# Horário: 09:00 - 11:00
# ------------------------------

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
from datetime import datetime

class HorarioEstudoluiza:
    def __init__(self, materia, dia, hora_inicio, hora_fim):
        self.materia = materia
        self.dia = dia
        self.__hora_inicio = hora_inicio  # agora é privado
        self.hora_fim = hora_fim

    # Getter para hora_inicio
    def get_hora_inicio(self):
        return self.__hora_inicio

    # Setter para hora_inicio
    def set_hora_inicio(self, nova_hora):
        self.__hora_inicio = nova_hora

    # Lógica interna: calcula duração do estudo
    def duracao_estudo(self):
        formato = "%H:%M"
        inicio = datetime.strptime(self.__hora_inicio, formato)
        fim = datetime.strptime(self.hora_fim, formato)
        duracao = fim - inicio
        return duracao

    def exibir_horario_luiza(self):
        print(f"Matéria: {self.materia}")
        print(f"Dia: {self.dia}")
        print(f"Horário: {self.__hora_inicio} - {self.hora_fim}")
        print(f"Duração: {self.duracao_estudo()}")
        print("-" * 30)


# Classe derivada (mantém o que você já tinha feito antes)
class HorarioEstudoAvancado(HorarioEstudoluiza):
    def __init__(self, materia, dia, hora_inicio, hora_fim, local):
        super().__init__(materia, dia, hora_inicio, hora_fim)
        self.local = local

    def exibir_local(self):
        print(f"Local de estudo: {self.local}")


# Exemplo de uso
estudo1 = HorarioEstudoluiza("Matemática", "Segunda-feira", "08:00", "10:00")
estudo1.exibir_horario_luiza()

# Usando get/set e verificando encapsulamento
print("Hora de início original:", estudo1.get_hora_inicio())
estudo1.set_hora_inicio("09:00")
print("Hora de início atualizada:", estudo1.get_hora_inicio())
estudo1.exibir_horario_luiza()
# Out:
# Matéria: Matemática
# Dia: Segunda-feira
# Horário: 08:00 - 10:00
# Duração: 2:00:00
# ------------------------------
# Hora de início original: 08:00
# Hora de início atualizada: 09:00
# Matéria: Matemática
# Dia: Segunda-feira
# Horário: 09:00 - 10:00
# Duração: 1:00:00
# ------------------------------

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
class HorarioEstudoluiza:
    lista_estudos = []  # lista simulando o "banco de dados"

    def __init__(self, materia, dia, inicio, fim):
        self.materia = materia
        self.dia = dia
        self.inicio = inicio
        self.fim = fim
        self.id = len(HorarioEstudoluiza.lista_estudos) + 1  # ID simples

    def exibir(self):
        print(f"{self.materia} | {self.dia} | {self.inicio} - {self.fim}")

    def salvar(self):
        HorarioEstudoluiza.lista_estudos.append(self)

    def listar(self):
        for estudo in HorarioEstudoluiza.lista_estudos:
            print(f"[ID {estudo.id}] {estudo.materia} | {estudo.dia} | {estudo.inicio} - {estudo.fim}")

    def excluir(self, id_excluir):
        HorarioEstudoluiza.lista_estudos = [
            e for e in HorarioEstudoluiza.lista_estudos if e.id != id_excluir
        ]
        print(f"Estudo com ID {id_excluir} removido.")


class HorarioEstudoAvancado(HorarioEstudoluiza):
    def __init__(self, materia, dia, inicio, fim, local):
        super().__init__(materia, dia, inicio, fim)
        self.local = local

    def exibir(self):  # Polimorfismo
        super().exibir()
        print(f"Local: {self.local}")


# Exemplo de uso
if __name__ == "__main__":
    estudo = HorarioEstudoAvancado("Português", "Quarta", "09:00", "10:30", "Sala 3")
    estudo.salvar()

    outro_estudo = HorarioEstudoluiza("Matemática", "Segunda", "08:00", "09:30")
    outro_estudo.salvar()

    print("\nHorários cadastrados:")
    estudo.listar()

    print("\nExcluindo o estudo com ID 1...\n")
    estudo.excluir(1)

    print("Horários restantes:")
    estudo.listar()
# Out:
# Horários cadastrados:
# [ID 1] Português | Quarta | 09:00 - 10:30
# [ID 2] Matemática | Segunda | 08:00 - 09:30
#
# Excluindo o estudo com ID 1...
#
# Estudo com ID 1 removido.
# Horários restantes:
# [ID 2] Matemática | Segunda | 08:00 - 09:30

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
class HorarioEstudoluiza:
    lista_estudos = []  # Lista simulando um banco de dados na memória

    def __init__(self, materia, dia, inicio, fim):
        self.materia = materia
        self.dia = dia
        self.inicio = inicio
        self.fim = fim
        self.id = len(HorarioEstudoluiza.lista_estudos) + 1  # ID automático simples

    def exibir(self):
        """Exibe os dados do horário de estudo"""
        print(f"{self.materia} | {self.dia} | {self.inicio} - {self.fim}")

    def salvar(self):
        """Salva o objeto na lista simulando o banco"""
        HorarioEstudoluiza.lista_estudos.append(self)

    def listar(self):
        """Lista todos os horários salvos"""
        print("\n--- HORÁRIOS DE ESTUDO ---")
        for estudo in HorarioEstudoluiza.lista_estudos:
            print(f"[ID {estudo.id}] {estudo.materia} | {estudo.dia} | {estudo.inicio} - {estudo.fim}")

    def excluir(self, id_excluir):
        """Remove um horário com base no ID"""
        original = len(HorarioEstudoluiza.lista_estudos)
        HorarioEstudoluiza.lista_estudos = [
            e for e in HorarioEstudoluiza.lista_estudos if e.id != id_excluir
        ]
        if len(HorarioEstudoluiza.lista_estudos) < original:
            print(f"\n Estudo com ID {id_excluir} removido.")
        else:
            print(f"\n Nenhum estudo encontrado com ID {id_excluir}.")


# Subclasse com polimorfismo (exibe também o local de estudo)
class HorarioEstudoAvancado(HorarioEstudoluiza):
    def __init__(self, materia, dia, inicio, fim, local):
        super().__init__(materia, dia, inicio, fim)
        self.local = local

    def exibir(self):  # Polimorfismo: sobrescreve o método exibir
        super().exibir()
        print(f"Local: {self.local}")


# ----------- Testes das funcionalidades -----------
if __name__ == "__main__":
    # Criando objetos
    estudo1 = HorarioEstudoAvancado("Português", "Segunda", "08:00", "09:30", "Sala 3")
    estudo2 = HorarioEstudoluiza("Matemática", "Terça", "10:00", "11:00")
    estudo3 = HorarioEstudoluiza("História", "Quarta", "14:00", "15:30")

    # Salvando os estudos
    estudo1.salvar()
    estudo2.salvar()
    estudo3.salvar()

    # Exibindo individualmente (com polimorfismo em ação)
    print("Exibindo estudos individualmente:\n")
    estudo1.exibir()
    estudo2.exibir()

    # Listando todos os estudos
    estudo1.listar()

    # Excluindo um horário pelo ID
    estudo1.excluir(2)
#teste
    # Listando após exclusão
    estudo1.listar()
# Out:
# Exibindo estudos individualmente:
#
# Português | Segunda | 08:00 - 09:30
# Local: Sala 3
# Matemática | Terça | 10:00 - 11:00
#
# --- HORÁRIOS DE ESTUDO ---
# [ID 1] Português | Segunda | 08:00 - 09:30
# [ID 1] Matemática | Terça | 10:00 - 11:00
# [ID 1] História | Quarta | 14:00 - 15:30
#
#  Nenhum estudo encontrado com ID 2.
#
# --- HORÁRIOS DE ESTUDO ---
# [ID 1] Português | Segunda | 08:00 - 09:30
# [ID 1] Matemática | Terça | 10:00 - 11:00
# [ID 1] História | Quarta | 14:00 - 15:30
